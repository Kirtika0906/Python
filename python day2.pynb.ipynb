# %%
cities=("delhi", "mumbai", "rajasthan", "harayana", "punjab")
print(cities[0:3])
print(cities[::-1])
print(len(cities))
# Out:
# ('delhi', 'mumbai', 'rajasthan')
# ('punjab', 'harayana', 'rajasthan', 'mumbai', 'delhi')
# 5

# %%
marks=[60,20,70,40,10]
print(min(marks))
print(max(marks))
print(sum(marks))
marks.sort()
print(marks)
marks.reverse()
print(marks)
# Out:
# 10
# 70
# 200
# [10, 20, 40, 60, 70]
# [70, 60, 40, 20, 10]
