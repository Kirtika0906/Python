# %%
name="python programming learning"
print(name[::-1])
print(name.count("p"))
print(name[:5:])
# Out:
# gninrael gnimmargorp nohtyp
# 2
# pytho

# %%
cities=("delhi", "mumbai", "rajasthan", "harayana", "punjab")
print(cities[0:3])
print(cities[::-1])
print(len(cities))
# Out:
# ('delhi', 'mumbai', 'rajasthan')
# ('punjab', 'harayana', 'rajasthan', 'mumbai', 'delhi')
# 5
